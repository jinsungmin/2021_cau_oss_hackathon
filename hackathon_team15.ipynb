# %% [markdown]
# <a href="https://colab.research.google.com/github/jinsungmin/2021_cau_oss_hackathon/blob/main/hackathon_team15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **0. 해커톤 진행 주의사항**
#
# **1)  개발 관련 주의사항**
# *   [1. 초기 환경 설정]은 절대 수정하지 말 것
# *   모든 구현은 [2. 데이터 전처리] 및 [3.모델 생성]에서만 진행
# *   [4. 모델 저장]에서 team_name 변수 변경 (예.`team_name = 'team01'`)
#  *    트레이닝 중간에 checkpoint를 활용하여 모델을 저장한 경우에도 파일 이름 양식 통일 필수
# *   Colab 사용중 실수로 데이터 손실이 발생할 수도 있으니 중간 결과값을 github에 업로드
#  *    "런타임->모든 런타임 재설정"은 절대 누르지 말 것 (저장한 모델 데이터가 모두 삭제됨)
# *   효율적인 구현 및 테스팅을 위해 GPU 가속 기능 활성화
#  *    "런타임 -> 런타임 유형변경 -> 하드웨어 가속기 -> GPU 설정"
# *   주석을 최대한 자세히 작성
# *   Keras API 관련하여 [Keras Documentation](https://keras.io/) 참조
#
# **2) 제출 관련 주의사항**
# *  제출물
#  *  소스코드 (hackathon_teamXX.ipynb)
#  *  컴파일된 모델 파일 (model_entire_teamXX.h5)
#  *  모델 발표 자료
# * 제출 기한: **오후 6시 (단, 발표자료는 12시)**
# * 제출 방법: [GitHub README](https://github.com/cauosshackathonta/2021_cau_oss_hackathon/) 참조
#
#
# **3) 평가 관련 주의사항**
# *  모델 성능 = 두개의 테스트 데이터 셋 분류 정확도에 대한 weighted sum
#  *  model.evaluate(x_test1, y_test1) + model.evaluate(x_test2, y_test2) * 2
# *  제출된 모델들의 테스트 데이터 셋 분류 정확도를 기준으로 수상작 결정
# *  수상 후보들에 대해서는 소스코드를 기반으로 모델 재검증
#
# **4) 수상 실격 사유**
# *  유사한 소스코드 or 알고리즘이 적발될 경우
# *  소스코드와 제출된 모델이 상이한 경우
# *  개발 관련 주의사항을 지키지 않은 경우
#  *  예: [초기 환경 설정]을 수정한 경우
# *  데이터 셋을 변조한 경우
#  *  예: 테스트 데이터 셋을 트레이닝 데이터 셋에 포함하여 모델 생성
#  *  단, tensorflow.data 및 dataset API를 사용하기 위해 변경하는 것은 허용. 이 경우, model evaluation 파트도 해당 API를 쓰도록 변경
# *  주석이 소스코드와 맞지 않거나 미비할 경우

# %% [markdown]
# # **1. 초기 환경 설정**

# %%
# tensorflow와 tf.keras 및 관련 라이브러리 임포트
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
from keras.utils import np_utils

# 데이터셋 로드 (Training dataset: CIFAR10, test dataset: CIFAR10 & CIFAR10의 변형)
(x_train, y_train), (x_test1, y_test1) = keras.datasets.cifar10.load_data()

test_ds2 = tfds.load('cifar10_1/v6', split='test', shuffle_files=False, batch_size=-1)
test_ds2 = tfds.as_numpy(test_ds2)
x_test2, y_test2 = test_ds2['image'], test_ds2['label']

#분류를 위해 클래스 벡터를 바이너리 매트릭스로 변환
y_train = np_utils.to_categorical(y_train)
y_test1 = np_utils.to_categorical(y_test1)
y_test2 = np_utils.to_categorical(y_test2)

# 총 클래스 개수
num_classes = y_train.shape[1]
input_shape = x_train.shape[1:]
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/dataset_builder.py:598: get_single_element (from tensorflow.python.data.experimental.ops.get_single_element) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.get_single_element()`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/dataset_builder.py:598: get_single_element (from tensorflow.python.data.experimental.ops.get_single_element) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.get_single_element()`.

# %% [markdown]
# # **2. 데이터 전처리**

# %%
# 데이터 전처리 (예: normalization)
# 원본 데이터와 전처리 후 데이터를 구분하기 위해, 변수명 x_train_after, x_test1_after, x_test2_after를 변경하지 말 것
x_train_after = x_train / 255.0
x_test1_after = x_test1 / 255.0
x_test2_after = x_test2 / 255.0

#y_train = np.vstack((y_train,y_train))
#print(y_train.shape)

# %% [markdown]
# # **3. 모델 생성**

# %%
model = keras.Sequential()

# Feature 
model.add(keras.layers.Conv2D(64, kernel_size=(3,3), padding='valid', input_shape=input_shape, activation=tf.nn.relu))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(keras.layers.Dropout(0.25))

model.add(keras.layers.Conv2D(128, kernel_size=(3,3),padding='valid', activation=tf.nn.relu))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(keras.layers.Dropout(0.25))

model.add(keras.layers.Conv2D(256, kernel_size=(3,3), activation=tf.nn.relu))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(keras.layers.Dropout(0.25))

# 3차원 tensor를 1차원 vector로 변환
model.add(keras.layers.Flatten(input_shape=input_shape))

# Classifier
model.add(keras.layers.Dense(256, activation=tf.nn.relu))
model.add(keras.layers.Dropout(0.25))

# 출력층
model.add(keras.layers.Dense(num_classes, activation=tf.nn.softmax))



# 모델 컴파일
# optimizer: 모델을 업데이트 하는 방식
# loss: 모델의 정확도를 판단하는 방식
# metrics: 트레이닝 및 테스팅 성능 모니터링을 위한 평가지표
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


# 체크포인트 생성
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath='/content/checkpoint_entire_best.h5', monitor='val_accuracy', verbose=1, save_weight_only=False, save_best_only=True, mode='auto')

# 모델 트레이닝
# batch_size: 전체 데이터셋 중 몇개씩 학습시킬 것인지
# epoch: 학습에 전체 데이터셋이 총 몇번 이용될 것인지
# shuffle: 학습전에 트레이닝 데이터셋을 랜덤하게 섞을 것인지
# validation_data: 중간 성능 검증에 사용할 data set (x_test1_after, x_test2_after, 혹은 둘을 merge해서 사용)
model.fit(x_train_after, y_train, batch_size = 128, epochs = 100, shuffle=True, callbacks=[cp_callback], validation_data=(x_test2_after, y_test2))
# Out:
# Epoch 1/100
# 391/391 [==============================] - 9s 21ms/step - loss: 1.6570 - accuracy: 0.3863 - val_loss: 1.6013 - val_accuracy: 0.4160
#
# Epoch 00001: val_accuracy improved from -inf to 0.41600, saving model to /content/checkpoint_entire_best.h5
# Epoch 2/100
# 391/391 [==============================] - 8s 20ms/step - loss: 1.2711 - accuracy: 0.5454 - val_loss: 1.4554 - val_accuracy: 0.4925
#
# Epoch 00002: val_accuracy improved from 0.41600 to 0.49250, saving model to /content/checkpoint_entire_best.h5
# Epoch 3/100
# 391/391 [==============================] - 8s 19ms/step - loss: 1.1115 - accuracy: 0.6058 - val_loss: 1.3613 - val_accuracy: 0.5270
#
# Epoch 00003: val_accuracy improved from 0.49250 to 0.52700, saving model to /content/checkpoint_entire_best.h5
# Epoch 4/100
# 391/391 [==============================] - 8s 19ms/step - loss: 1.0049 - accuracy: 0.6480 - val_loss: 1.2954 - val_accuracy: 0.5440
#
# Epoch 00004: val_accuracy improved from 0.52700 to 0.54400, saving model to /content/checkpoint_entire_best.h5
# Epoch 5/100
# 391/391 [==============================] - 8s 19ms/step - loss: 0.9197 - accuracy: 0.6782 - val_loss: 1.2494 - val_accuracy: 0.5565
#
# Epoch 00005: val_accuracy improved from 0.54400 to 0.55650, saving model to /content/checkpoint_entire_best.h5
# Epoch 6/100
# 391/391 [==============================] - 8s 19ms/step - loss: 0.8524 - accuracy: 0.7028 - val_loss: 1.2220 - val_accuracy: 0.5860
#
# Epoch 00006: val_accuracy improved from 0.55650 to 0.58600, saving model to /content/checkpoint_entire_best.h5
# Epoch 7/100
# 391/391 [==============================] - 8s 19ms/step - loss: 0.8150 - accuracy: 0.7162 - val_loss: 1.2042 - val_accuracy: 0.5890
#
# Epoch 00007: val_accuracy improved from 0.58600 to 0.58900, saving model to /content/checkpoint_entire_best.h5
# Epoch 8/100
# 391/391 [==============================] - 8s 19ms/step - loss: 0.7752 - accuracy: 0.7295 - val_loss: 1.1362 - val_accuracy: 0.6040
#
# Epoch 00008: val_accuracy improved from 0.58900 to 0.60400, saving model to /content/checkpoint_entire_best.h5
# Epoch 9/100
# 391/391 [==============================] - 8s 19ms/step - loss: 0.7333 - accuracy: 0.7414 - val_loss: 1.2291 - val_accuracy: 0.5945
#
# Epoch 00009: val_accuracy did not improve from 0.60400
# Epoch 10/100
# 391/391 [==============================] - 8s 19ms/step - loss: 0.7063 - accuracy: 0.7501 - val_loss: 1.0940 - val_accuracy: 0.6300
#
# Epoch 00010: val_accuracy improved from 0.60400 to 0.63000, saving model to /content/checkpoint_entire_best.h5
# Epoch 11/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.6739 - accuracy: 0.7633 - val_loss: 1.0760 - val_accuracy: 0.6365
#
# Epoch 00011: val_accuracy improved from 0.63000 to 0.63650, saving model to /content/checkpoint_entire_best.h5
# Epoch 12/100
# 391/391 [==============================] - 8s 19ms/step - loss: 0.6479 - accuracy: 0.7726 - val_loss: 1.0750 - val_accuracy: 0.6440
#
# Epoch 00012: val_accuracy improved from 0.63650 to 0.64400, saving model to /content/checkpoint_entire_best.h5
# Epoch 13/100
# 391/391 [==============================] - 8s 19ms/step - loss: 0.6289 - accuracy: 0.7795 - val_loss: 1.1071 - val_accuracy: 0.6310
#
# Epoch 00013: val_accuracy did not improve from 0.64400
# Epoch 14/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.6032 - accuracy: 0.7866 - val_loss: 1.0736 - val_accuracy: 0.6355
#
# Epoch 00014: val_accuracy did not improve from 0.64400
# Epoch 15/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.5835 - accuracy: 0.7950 - val_loss: 1.1049 - val_accuracy: 0.6370
#
# Epoch 00015: val_accuracy did not improve from 0.64400
# Epoch 16/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.5758 - accuracy: 0.7979 - val_loss: 1.1267 - val_accuracy: 0.6420
#
# Epoch 00016: val_accuracy did not improve from 0.64400
# Epoch 17/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.5610 - accuracy: 0.8004 - val_loss: 1.1000 - val_accuracy: 0.6390
#
# Epoch 00017: val_accuracy did not improve from 0.64400
# Epoch 18/100
# 391/391 [==============================] - 8s 19ms/step - loss: 0.5430 - accuracy: 0.8079 - val_loss: 1.0798 - val_accuracy: 0.6540
#
# Epoch 00018: val_accuracy improved from 0.64400 to 0.65400, saving model to /content/checkpoint_entire_best.h5
# Epoch 19/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.5272 - accuracy: 0.8126 - val_loss: 1.0623 - val_accuracy: 0.6490
#
# Epoch 00019: val_accuracy did not improve from 0.65400
# Epoch 20/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.5178 - accuracy: 0.8179 - val_loss: 1.0425 - val_accuracy: 0.6470
#
# Epoch 00020: val_accuracy did not improve from 0.65400
# Epoch 21/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.5055 - accuracy: 0.8201 - val_loss: 1.0403 - val_accuracy: 0.6615
#
# Epoch 00021: val_accuracy improved from 0.65400 to 0.66150, saving model to /content/checkpoint_entire_best.h5
# Epoch 22/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.5038 - accuracy: 0.8205 - val_loss: 1.0570 - val_accuracy: 0.6655
#
# Epoch 00022: val_accuracy improved from 0.66150 to 0.66550, saving model to /content/checkpoint_entire_best.h5
# Epoch 23/100
# 391/391 [==============================] - 8s 19ms/step - loss: 0.4891 - accuracy: 0.8262 - val_loss: 1.0712 - val_accuracy: 0.6550
#
# Epoch 00023: val_accuracy did not improve from 0.66550
# Epoch 24/100
# 391/391 [==============================] - 8s 19ms/step - loss: 0.4822 - accuracy: 0.8305 - val_loss: 1.0599 - val_accuracy: 0.6565
#
# Epoch 00024: val_accuracy did not improve from 0.66550
# Epoch 25/100
# 391/391 [==============================] - 7s 19ms/step - loss: 0.4747 - accuracy: 0.8318 - val_loss: 1.0378 - val_accuracy: 0.6590
#
# Epoch 00025: val_accuracy did not improve from 0.66550
# Epoch 26/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.4604 - accuracy: 0.8383 - val_loss: 1.0667 - val_accuracy: 0.6595
#
# Epoch 00026: val_accuracy did not improve from 0.66550
# Epoch 27/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.4633 - accuracy: 0.8357 - val_loss: 1.0519 - val_accuracy: 0.6620
#
# Epoch 00027: val_accuracy did not improve from 0.66550
# Epoch 28/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.4512 - accuracy: 0.8408 - val_loss: 1.1087 - val_accuracy: 0.6515
#
# Epoch 00028: val_accuracy did not improve from 0.66550
# Epoch 29/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.4403 - accuracy: 0.8433 - val_loss: 1.0758 - val_accuracy: 0.6730
#
# Epoch 00029: val_accuracy improved from 0.66550 to 0.67300, saving model to /content/checkpoint_entire_best.h5
# Epoch 30/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.4425 - accuracy: 0.8430 - val_loss: 1.1471 - val_accuracy: 0.6420
#
# Epoch 00030: val_accuracy did not improve from 0.67300
# Epoch 31/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.4304 - accuracy: 0.8486 - val_loss: 1.0633 - val_accuracy: 0.6650
#
# Epoch 00031: val_accuracy did not improve from 0.67300
# Epoch 32/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.4258 - accuracy: 0.8475 - val_loss: 1.1014 - val_accuracy: 0.6635
#
# Epoch 00032: val_accuracy did not improve from 0.67300
# Epoch 33/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.4231 - accuracy: 0.8508 - val_loss: 1.0876 - val_accuracy: 0.6665
#
# Epoch 00033: val_accuracy did not improve from 0.67300
# Epoch 34/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.4076 - accuracy: 0.8549 - val_loss: 1.1208 - val_accuracy: 0.6685
#
# Epoch 00034: val_accuracy did not improve from 0.67300
# Epoch 35/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.4140 - accuracy: 0.8535 - val_loss: 1.1694 - val_accuracy: 0.6600
#
# Epoch 00035: val_accuracy did not improve from 0.67300
# Epoch 36/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.4063 - accuracy: 0.8555 - val_loss: 1.1351 - val_accuracy: 0.6580
#
# Epoch 00036: val_accuracy did not improve from 0.67300
# Epoch 37/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3985 - accuracy: 0.8598 - val_loss: 1.0833 - val_accuracy: 0.6680
#
# Epoch 00037: val_accuracy did not improve from 0.67300
# Epoch 38/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3997 - accuracy: 0.8566 - val_loss: 1.0724 - val_accuracy: 0.6750
#
# Epoch 00038: val_accuracy improved from 0.67300 to 0.67500, saving model to /content/checkpoint_entire_best.h5
# Epoch 39/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3968 - accuracy: 0.8616 - val_loss: 1.1330 - val_accuracy: 0.6620
#
# Epoch 00039: val_accuracy did not improve from 0.67500
# Epoch 40/100
# 391/391 [==============================] - 8s 19ms/step - loss: 0.3850 - accuracy: 0.8644 - val_loss: 1.1314 - val_accuracy: 0.6660
#
# Epoch 00040: val_accuracy did not improve from 0.67500
# Epoch 41/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3824 - accuracy: 0.8634 - val_loss: 1.1566 - val_accuracy: 0.6665
#
# Epoch 00041: val_accuracy did not improve from 0.67500
# Epoch 42/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3819 - accuracy: 0.8644 - val_loss: 1.0874 - val_accuracy: 0.6705
#
# Epoch 00042: val_accuracy did not improve from 0.67500
# Epoch 43/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3758 - accuracy: 0.8673 - val_loss: 1.1336 - val_accuracy: 0.6615
#
# Epoch 00043: val_accuracy did not improve from 0.67500
# Epoch 44/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3747 - accuracy: 0.8675 - val_loss: 1.1878 - val_accuracy: 0.6615
#
# Epoch 00044: val_accuracy did not improve from 0.67500
# Epoch 45/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3719 - accuracy: 0.8675 - val_loss: 1.1749 - val_accuracy: 0.6645
#
# Epoch 00045: val_accuracy did not improve from 0.67500
# Epoch 46/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3688 - accuracy: 0.8693 - val_loss: 1.1545 - val_accuracy: 0.6590
#
# Epoch 00046: val_accuracy did not improve from 0.67500
# Epoch 47/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3632 - accuracy: 0.8713 - val_loss: 1.1788 - val_accuracy: 0.6670
#
# Epoch 00047: val_accuracy did not improve from 0.67500
# Epoch 48/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3657 - accuracy: 0.8693 - val_loss: 1.1856 - val_accuracy: 0.6700
#
# Epoch 00048: val_accuracy did not improve from 0.67500
# Epoch 49/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3571 - accuracy: 0.8746 - val_loss: 1.1381 - val_accuracy: 0.6630
#
# Epoch 00049: val_accuracy did not improve from 0.67500
# Epoch 50/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3552 - accuracy: 0.8749 - val_loss: 1.1260 - val_accuracy: 0.6545
#
# Epoch 00050: val_accuracy did not improve from 0.67500
# Epoch 51/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3546 - accuracy: 0.8764 - val_loss: 1.1430 - val_accuracy: 0.6595
#
# Epoch 00051: val_accuracy did not improve from 0.67500
# Epoch 52/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3482 - accuracy: 0.8769 - val_loss: 1.1782 - val_accuracy: 0.6650
#
# Epoch 00052: val_accuracy did not improve from 0.67500
# Epoch 53/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3469 - accuracy: 0.8782 - val_loss: 1.1795 - val_accuracy: 0.6610
#
# Epoch 00053: val_accuracy did not improve from 0.67500
# Epoch 54/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3469 - accuracy: 0.8771 - val_loss: 1.2055 - val_accuracy: 0.6565
#
# Epoch 00054: val_accuracy did not improve from 0.67500
# Epoch 55/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3496 - accuracy: 0.8754 - val_loss: 1.1491 - val_accuracy: 0.6610
#
# Epoch 00055: val_accuracy did not improve from 0.67500
# Epoch 56/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3390 - accuracy: 0.8796 - val_loss: 1.1874 - val_accuracy: 0.6550
#
# Epoch 00056: val_accuracy did not improve from 0.67500
# Epoch 57/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3354 - accuracy: 0.8812 - val_loss: 1.1216 - val_accuracy: 0.6670
#
# Epoch 00057: val_accuracy did not improve from 0.67500
# Epoch 58/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3347 - accuracy: 0.8804 - val_loss: 1.1746 - val_accuracy: 0.6720
#
# Epoch 00058: val_accuracy did not improve from 0.67500
# Epoch 59/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3355 - accuracy: 0.8815 - val_loss: 1.1899 - val_accuracy: 0.6540
#
# Epoch 00059: val_accuracy did not improve from 0.67500
# Epoch 60/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3279 - accuracy: 0.8843 - val_loss: 1.2198 - val_accuracy: 0.6610
#
# Epoch 00060: val_accuracy did not improve from 0.67500
# Epoch 61/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3251 - accuracy: 0.8847 - val_loss: 1.1547 - val_accuracy: 0.6760
#
# Epoch 00061: val_accuracy improved from 0.67500 to 0.67600, saving model to /content/checkpoint_entire_best.h5
# Epoch 62/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3242 - accuracy: 0.8854 - val_loss: 1.1825 - val_accuracy: 0.6760
#
# Epoch 00062: val_accuracy did not improve from 0.67600
# Epoch 63/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3282 - accuracy: 0.8848 - val_loss: 1.1761 - val_accuracy: 0.6650
#
# Epoch 00063: val_accuracy did not improve from 0.67600
# Epoch 64/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3214 - accuracy: 0.8867 - val_loss: 1.1499 - val_accuracy: 0.6665
#
# Epoch 00064: val_accuracy did not improve from 0.67600
# Epoch 65/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3212 - accuracy: 0.8867 - val_loss: 1.1761 - val_accuracy: 0.6675
#
# Epoch 00065: val_accuracy did not improve from 0.67600
# Epoch 66/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3160 - accuracy: 0.8888 - val_loss: 1.2054 - val_accuracy: 0.6550
#
# Epoch 00066: val_accuracy did not improve from 0.67600
# Epoch 67/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3174 - accuracy: 0.8882 - val_loss: 1.1575 - val_accuracy: 0.6695
#
# Epoch 00067: val_accuracy did not improve from 0.67600
# Epoch 68/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3114 - accuracy: 0.8902 - val_loss: 1.2348 - val_accuracy: 0.6735
#
# Epoch 00068: val_accuracy did not improve from 0.67600
# Epoch 69/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3100 - accuracy: 0.8905 - val_loss: 1.1356 - val_accuracy: 0.6785
#
# Epoch 00069: val_accuracy improved from 0.67600 to 0.67850, saving model to /content/checkpoint_entire_best.h5
# Epoch 70/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3059 - accuracy: 0.8925 - val_loss: 1.2212 - val_accuracy: 0.6650
#
# Epoch 00070: val_accuracy did not improve from 0.67850
# Epoch 71/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3105 - accuracy: 0.8911 - val_loss: 1.2457 - val_accuracy: 0.6675
#
# Epoch 00071: val_accuracy did not improve from 0.67850
# Epoch 72/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3063 - accuracy: 0.8916 - val_loss: 1.2671 - val_accuracy: 0.6675
#
# Epoch 00072: val_accuracy did not improve from 0.67850
# Epoch 73/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3153 - accuracy: 0.8887 - val_loss: 1.2278 - val_accuracy: 0.6665
#
# Epoch 00073: val_accuracy did not improve from 0.67850
# Epoch 74/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3079 - accuracy: 0.8907 - val_loss: 1.1982 - val_accuracy: 0.6780
#
# Epoch 00074: val_accuracy did not improve from 0.67850
# Epoch 75/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3068 - accuracy: 0.8933 - val_loss: 1.2243 - val_accuracy: 0.6665
#
# Epoch 00075: val_accuracy did not improve from 0.67850
# Epoch 76/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2957 - accuracy: 0.8959 - val_loss: 1.1903 - val_accuracy: 0.6745
#
# Epoch 00076: val_accuracy did not improve from 0.67850
# Epoch 77/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3054 - accuracy: 0.8923 - val_loss: 1.2488 - val_accuracy: 0.6655
#
# Epoch 00077: val_accuracy did not improve from 0.67850
# Epoch 78/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.3003 - accuracy: 0.8934 - val_loss: 1.1783 - val_accuracy: 0.6780
#
# Epoch 00078: val_accuracy did not improve from 0.67850
# Epoch 79/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2928 - accuracy: 0.8980 - val_loss: 1.2121 - val_accuracy: 0.6745
#
# Epoch 00079: val_accuracy did not improve from 0.67850
# Epoch 80/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2985 - accuracy: 0.8961 - val_loss: 1.1969 - val_accuracy: 0.6740
#
# Epoch 00080: val_accuracy did not improve from 0.67850
# Epoch 81/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2895 - accuracy: 0.8976 - val_loss: 1.2048 - val_accuracy: 0.6800
#
# Epoch 00081: val_accuracy improved from 0.67850 to 0.68000, saving model to /content/checkpoint_entire_best.h5
# Epoch 82/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2979 - accuracy: 0.8955 - val_loss: 1.2076 - val_accuracy: 0.6660
#
# Epoch 00082: val_accuracy did not improve from 0.68000
# Epoch 83/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2943 - accuracy: 0.8980 - val_loss: 1.1994 - val_accuracy: 0.6710
#
# Epoch 00083: val_accuracy did not improve from 0.68000
# Epoch 84/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2864 - accuracy: 0.8996 - val_loss: 1.1870 - val_accuracy: 0.6650
#
# Epoch 00084: val_accuracy did not improve from 0.68000
# Epoch 85/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2890 - accuracy: 0.8981 - val_loss: 1.1825 - val_accuracy: 0.6770
#
# Epoch 00085: val_accuracy did not improve from 0.68000
# Epoch 86/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2931 - accuracy: 0.8976 - val_loss: 1.1847 - val_accuracy: 0.6695
#
# Epoch 00086: val_accuracy did not improve from 0.68000
# Epoch 87/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2859 - accuracy: 0.8985 - val_loss: 1.2019 - val_accuracy: 0.6680
#
# Epoch 00087: val_accuracy did not improve from 0.68000
# Epoch 88/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2888 - accuracy: 0.8979 - val_loss: 1.2296 - val_accuracy: 0.6645
#
# Epoch 00088: val_accuracy did not improve from 0.68000
# Epoch 89/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2843 - accuracy: 0.9003 - val_loss: 1.1900 - val_accuracy: 0.6660
#
# Epoch 00089: val_accuracy did not improve from 0.68000
# Epoch 90/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2773 - accuracy: 0.9042 - val_loss: 1.2116 - val_accuracy: 0.6680
#
# Epoch 00090: val_accuracy did not improve from 0.68000
# Epoch 91/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2825 - accuracy: 0.9020 - val_loss: 1.2570 - val_accuracy: 0.6700
#
# Epoch 00091: val_accuracy did not improve from 0.68000
# Epoch 92/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2799 - accuracy: 0.9005 - val_loss: 1.1971 - val_accuracy: 0.6640
#
# Epoch 00092: val_accuracy did not improve from 0.68000
# Epoch 93/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2794 - accuracy: 0.9014 - val_loss: 1.2310 - val_accuracy: 0.6625
#
# Epoch 00093: val_accuracy did not improve from 0.68000
# Epoch 94/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2788 - accuracy: 0.9028 - val_loss: 1.2205 - val_accuracy: 0.6740
#
# Epoch 00094: val_accuracy did not improve from 0.68000
# Epoch 95/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2720 - accuracy: 0.9053 - val_loss: 1.2064 - val_accuracy: 0.6660
#
# Epoch 00095: val_accuracy did not improve from 0.68000
# Epoch 96/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2778 - accuracy: 0.9039 - val_loss: 1.2109 - val_accuracy: 0.6700
#
# Epoch 00096: val_accuracy did not improve from 0.68000
# Epoch 97/100
# 391/391 [==============================] - 8s 21ms/step - loss: 0.2829 - accuracy: 0.9016 - val_loss: 1.2430 - val_accuracy: 0.6585
#
# Epoch 00097: val_accuracy did not improve from 0.68000
# Epoch 98/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2688 - accuracy: 0.9047 - val_loss: 1.2907 - val_accuracy: 0.6645
#
# Epoch 00098: val_accuracy did not improve from 0.68000
# Epoch 99/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2752 - accuracy: 0.9033 - val_loss: 1.2627 - val_accuracy: 0.6655
#
# Epoch 00099: val_accuracy did not improve from 0.68000
# Epoch 100/100
# 391/391 [==============================] - 8s 20ms/step - loss: 0.2715 - accuracy: 0.9043 - val_loss: 1.2546 - val_accuracy: 0.6740
#
# Epoch 00100: val_accuracy did not improve from 0.68000

# %% [markdown]
# # **4. 모델 저장**

# %%
save_path = '/content/'
team_name = 'team15'

# 트레이닝된 전체 모델을 저장합니다.
model.save(save_path +  'model_entire_'+ team_name + '.h5')

# %% [markdown]
# # **5. 모델 로드 및 평가**

# %%
save_path = '/content/'
team_name = 'team15'

model = keras.models.load_model(save_path + 'model_entire_' + team_name + '.h5')

model.evaluate(x_test1_after, y_test1)
model.evaluate(x_test2_after, y_test2)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6920 - accuracy: 0.8054
# 63/63 [==============================] - 0s 6ms/step - loss: 1.2546 - accuracy: 0.6740
# [1.254598617553711, 0.6740000247955322]
